# %%
import pandas as pd
from sodapy import Socrata
import os
from dotenv import load_dotenv

load_dotenv('.env')
TOKEN_APP = os.getenv("SECRET_TOKEN")
TOKEN_USER = os.getenv("TOKEN_USER")
TOKEN_PASS = os.getenv("TOKE_PASS")

client = Socrata(
        "www.datos.gov.co",
        TOKEN_APP,
        username= TOKEN_USER,
        password= TOKEN_PASS,
        timeout=5000)


consulta =  """SELECT fecha_de_notificaci_n, id_de_caso, departamento_nom, edad, sexo, estado, 
recuperado, fecha_inicio_sintomas, fecha_muerte, fecha_recuperado
limit 1000"""
data_id = "gt2j-8ykr"

results = client.get(data_id, query = consulta)
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df.head()
# Out:
#   fecha_de_notificaci_n id_de_caso departamento_nom edad sexo     estado  \
# 0   2020-12-22 00:00:00    1556979            VALLE   67    F       Leve
# 1   2020-12-19 00:00:00    1556980            VALLE   66    F       Leve
# 2   2020-12-19 00:00:00    1556981            VALLE   68    F       Leve
# 3   2020-12-22 00:00:00    1556982            VALLE   74    F  Fallecido
# 4   2020-12-22 00:00:00    1556983            VALLE   65    F       Leve
#
#    recuperado fecha_inicio_sintomas     fecha_recuperado         fecha_muerte
# 0  Recuperado   2020-12-21 00:00:00  2021-01-04 00:00:00                  NaN
# 1  Recuperado   2020-12-07 00:00:00  2020-12-25 00:00:00                  NaN
# 2  Recuperado   2020-12-18 00:00:00  2021-01-01 00:00:00                  NaN
# 3   Fallecido   2020-12-17 00:00:00                  NaN  2020-12-30 00:00:00
# 4  Recuperado   2020-12-21 00:00:00  2021-01-04 00:00:00                  NaN
